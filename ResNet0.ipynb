# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}



# !mkdir -p drive

# !google-drive-ocamlfuse drive
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131289 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.6-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.6-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.6-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !ls -drive
# Out:
# ls: invalid option -- 'e'
# Try 'ls --help' for more information.

# %%
# !unzip -q /content/drive/images.zip
# !ls
# Out:
# adc.json  drive  images  sample_data  test.txt	train.txt  val.txt

# %%
import tensorflow as tf
from tensorflow.python.training.moving_averages import assign_moving_average
import numpy as np
import os, pdb
import cv2
import numpy as np
import random as rn
import tensorflow as tf
import threading
import time

global n_classes, ema_gp
ema_gp = []
n_classes = 50

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def activation(x,name="activation"):
    return tf.nn.relu(x, name=name)
    
def conv2d(name, l_input, w, b, s, p):
    l_input = tf.nn.conv2d(l_input, w, strides=[1,s,s,1], padding=p, name=name)
    l_input = l_input+b

    return l_input

def batchnorm(conv, isTraining, name='bn'):
    return tf.layers.batch_normalization(conv, training=isTraining, name="bn"+name)

def initializer(in_filters, out_filters, name):
    w1 = tf.get_variable(name+"W", [3, 3, in_filters, out_filters], initializer=tf.truncated_normal_initializer())
    b1 = tf.get_variable(name+"B", [out_filters], initializer=tf.truncated_normal_initializer())
    return w1, b1
  
def residual_block(in_x, in_filters, out_filters, stride, isDownSampled, name, isTraining):
    global ema_gp
    # first convolution layer
    if isDownSampled:
      in_x = tf.nn.avg_pool(in_x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
      
    x = batchnorm(in_x, isTraining, name=name+'FirstBn')
    x = activation(x)
    w1, b1 = initializer(in_filters, in_filters, name+"first_res")
    x = conv2d(name+'r1', x, w1, b1, 1, "SAME")

    # second convolution layer
    x = batchnorm(x, isTraining, name=name+'SecondBn')
    x = activation(x)
    w2, b2 = initializer(in_filters, out_filters, name+"Second_res")
    x = conv2d(name+'r2', x, w2, b2, 1, "SAME")
    
    if in_filters != out_filters:
        difference = out_filters - in_filters
        left_pad = difference // 2
        right_pad = difference - left_pad
        identity = tf.pad(in_x, [[0, 0], [0, 0], [0, 0], [left_pad, right_pad]])
        return x + identity
    else:
        return in_x + x

      
def ResNet(_X, isTraining):
    global n_classes
    w1 = tf.get_variable("initW", [7, 7, 3, 96], initializer=tf.truncated_normal_initializer())
    b1 = tf.get_variable("initB", [96], initializer=tf.truncated_normal_initializer())
    x = conv2d('conv1', _X, w1, b1, 4, "VALID")
    
    filters_num = [96,128,256,384]
    block_num = [2,2,2,2]
    l_cnt = 1
    for i in range(len(filters_num)):
      for j in range(block_num[i]):
          
          if ((j==block_num[i]-1) & (i<len(filters_num)-1)):
            x = residual_block(x, filters_num[i], filters_num[i+1], 2, True, 'ResidualBlock%d'%(l_cnt), isTraining)
            print('[L-%d] Build %dth connection layer %d from %d to %d channels' % (l_cnt, i, j, filters_num[i], filters_num[i+1]))
          else:
            x = residual_block(x, filters_num[i], filters_num[i], 1, False, 'ResidualBlock%d'%(l_cnt), isTraining)
            print('[L-%d] Build %dth residual block %d with %d channels' % (l_cnt,i, j, filters_num[i]))
          l_cnt +=1

    
    wo, bo=initializer(filters_num[-1], n_classes, "FinalOutput")
    x = conv2d('final', x, wo, bo, 1, "SAME")
    
    x = activation(x)
    x = batchnorm(x, isTraining, name='FinalBn')
    
    x = tf.reduce_mean(x, [1,2])
    W = tf.get_variable("FinalW", [n_classes, n_classes], initializer=tf.truncated_normal_initializer())
    b = tf.get_variable("FinalB", [n_classes], initializer=tf.truncated_normal_initializer())
    
    out = tf.matmul(x, W) + b
                            

    return out

# %%
#==========================================================================
#=============Reading data in multithreading manner========================
#==========================================================================
def read_labeled_image_list(image_list_file, training_img_dir):
    """Reads a .txt file containing pathes and labeles
    Args:
       image_list_file: a .txt file with one /path/to/image per line
       label: optionally, if set label will be pasted after each line
    Returns:
       List with all filenames in file image_list_file
    """
    f = open(image_list_file, 'r')
    filenames = []
    labels = []

    for line in f:
        filename, label = line[:-1].split(' ')
        filename = training_img_dir+filename
        filenames.append(filename)
        labels.append(int(label))
        
    return filenames, labels
    
    
def read_images_from_disk(input_queue, size1=256):
    """Consumes a single filename and label as a ' '-delimited string.
    Args:
      filename_and_label_tensor: A scalar string tensor.
    Returns:
      Two tensors: the decoded image, and the string label.
    """
    label = input_queue[1]
    fn=input_queue[0]
    file_contents = tf.read_file(input_queue[0])
    example = tf.image.decode_jpeg(file_contents, channels=3)
    
    #example = tf.image.decode_png(file_contents, channels=3, name="dataset_image") # png fo rlfw
    example=tf.image.resize_images(example, [size1,size1])
    return example, label, fn
    
def setup_inputs(sess, filenames, training_img_dir, image_size=256, crop_size=224, isTest=False, batch_size=128):
    
    # Read each image file
    image_list, label_list = read_labeled_image_list(filenames, training_img_dir)

    images = tf.cast(image_list, tf.string)
    labels = tf.cast(label_list, tf.int64)
     # Makes an input queue
    if isTest is False:
        isShuffle = True
        numThr = 4
    else:
        isShuffle = False
        numThr = 1
        
    input_queue = tf.train.slice_input_producer([images, labels], shuffle=isShuffle)
    image, y,fn = read_images_from_disk(input_queue)

    channels = 3
    image.set_shape([None, None, channels])
        
    # Crop and other random augmentations
    if isTest is False:
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_saturation(image, .95, 1.05)
        image = tf.image.random_brightness(image, .05)
        image = tf.image.random_contrast(image, .95, 1.05)
        

    image = tf.random_crop(image, [crop_size, crop_size, 3])
    image = tf.cast(image, tf.float32)/255.0
    
    image, y,fn = tf.train.batch([image, y, fn], batch_size=batch_size, capacity=batch_size*3, num_threads=numThr, name='labels_and_images')

    tf.train.start_queue_runners(sess=sess)

    return image, y, fn, len(label_list)

# %%
batch_size = 128
display_step = 80
learning_rate = tf.placeholder(tf.float32)      # Learning rate to be fed
lr = 1e-2                          # Learning rate start
print('GO!!')
# Out:
# GO!!

# %%
# Setup the tensorflow...
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

print("Preparing the training & validation data...")
train_data, train_labels, filelist1, glen1 = setup_inputs(sess, "train.txt", "./", batch_size=batch_size)
val_data, val_labels, filelist2, tlen1 = setup_inputs(sess, "val.txt", "./", batch_size=batch_size,isTest=True)


max_iter = glen1*100
print("Preparing the training model with learning rate = %.5f..." % (lr))


with tf.variable_scope("ResNet") as scope:
  pred = ResNet(train_data, True)
  scope.reuse_variables()
  valpred = ResNet(val_data, False)

with tf.name_scope('Loss_and_Accuracy'):
  update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
  with tf.control_dependencies(update_ops):
    cost = tf.losses.sparse_softmax_cross_entropy(labels=train_labels, logits=pred)
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    
  correct_prediction = tf.equal(tf.argmax(pred, 1), train_labels)
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
  top5=tf.reduce_mean(tf.cast(tf.nn.in_top_k(pred, train_labels, 5), tf.float32))
  
  correct_prediction2 = tf.equal(tf.argmax(valpred, 1), val_labels)
  accuracy2 = tf.reduce_mean(tf.cast(correct_prediction2, tf.float32))
  
  tf.summary.scalar('Loss', cost)
  tf.summary.scalar('Training_Accuracy', accuracy)
  tf.summary.scalar('Top-5_accuracy', top5)
# Out:
# Preparing the training & validation data...
# WARNING: Logging before flag parsing goes to stderr.
# W0816 04:47:17.002232 139712017106816 deprecation.py:323] From <ipython-input-6-fbefbd28a462>:53: slice_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(tuple(tensor_list)).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0816 04:47:17.009375 139712017106816 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:374: range_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.range(limit).shuffle(limit).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0816 04:47:17.025459 139712017106816 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:320: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0816 04:47:17.027328 139712017106816 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:190: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# W0816 04:47:17.030472 139712017106816 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0816 04:47:17.032935 139712017106816 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0816 04:47:17.086661 139712017106816 deprecation.py:323] From <ipython-input-6-fbefbd28a462>:70: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# W0816 04:47:17.095786 139712017106816 deprecation.py:323] From <ipython-input-6-fbefbd28a462>:72: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# Preparing the training model with learning rate = 0.01000...
# W0816 04:47:18.334917 139712017106816 deprecation.py:323] From <ipython-input-5-e493ffb64f84>:12: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# [L-1] Build 0th residual block 0 with 96 channels
# [L-2] Build 0th connection layer 1 from 96 to 128 channels
# [L-3] Build 1th residual block 0 with 128 channels
# [L-4] Build 1th connection layer 1 from 128 to 256 channels
# [L-5] Build 2th residual block 0 with 256 channels
# [L-6] Build 2th connection layer 1 from 256 to 384 channels
# [L-7] Build 3th residual block 0 with 384 channels
# [L-8] Build 3th residual block 1 with 384 channels
# [L-1] Build 0th residual block 0 with 96 channels
# [L-2] Build 0th connection layer 1 from 96 to 128 channels
# [L-3] Build 1th residual block 0 with 128 channels
# [L-4] Build 1th connection layer 1 from 128 to 256 channels
# [L-5] Build 2th residual block 0 with 256 channels
# [L-6] Build 2th connection layer 1 from 256 to 384 channels
# [L-7] Build 3th residual block 0 with 384 channels
# [L-8] Build 3th residual block 1 with 384 channels
# W0816 04:47:20.297724 139712017106816 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
saver = tf.train.Saver()
init = tf.global_variables_initializer()
sess.run(init)
step = 0
writer = tf.summary.FileWriter("log2", sess.graph)
summaries = tf.summary.merge_all()

print("We are going to train the ImageNet model based on ResNet!!!")
while (step * batch_size) < max_iter:
    epoch1=np.floor((step*batch_size)/glen1)
    if (((step*batch_size)%glen1 < batch_size) & (lr==1e-3) & (epoch1 >2)):
        lr /= 10

    sess.run(optimizer,  feed_dict={learning_rate: lr})
 
    if (step % 15000==1) & (step>15000):
        save_path = saver.save(sess, "./tf_resnet_model_iter" + str(step) + ".ckpt")
        print("Model saved in file at iteration %d: %s" % (step*batch_size,save_path))

    if step>1 and step % display_step == 1:
        # calculate the loss
        loss, acc, top5acc, summaries_string = sess.run([cost, accuracy,top5, summaries])
        print("Iter=%d/epoch=%d, Loss=%.6f, Training Accuracy=%.6f, Top-5 Accuracy=%.6f, lr=%f" % (step*batch_size, epoch1 ,loss, acc, top5acc, lr))
        writer.add_summary(summaries_string, step)
        
    if step>1 and (step % (display_step*10) == 1):
        rounds = tlen1 // batch_size
        valacc=[]
        for k in range(rounds):
          a2 = sess.run(accuracy2)
          valacc.append(a2)
        print("\nIter=%d/epoch=%d, Validation Accuracy=%.6f" % (step*batch_size, epoch1 , np.mean(valacc)))

  
    step += 1
print("Optimization Finished!")
save_path = saver.save(sess, "./tf_resnet_model.ckpt")
print("Model saved in file: %s" % save_path)
# Out:
# We are going to train the ImageNet model based on ResNet!!!
# Iter=10368/epoch=0, Loss=3.485845, Training Accuracy=0.085938, Top-5 Accuracy=0.367188, lr=0.010000
# Iter=20608/epoch=0, Loss=3.171478, Training Accuracy=0.156250, Top-5 Accuracy=0.507812, lr=0.010000
# Iter=30848/epoch=0, Loss=2.910992, Training Accuracy=0.195312, Top-5 Accuracy=0.531250, lr=0.010000
# Iter=41088/epoch=0, Loss=2.668463, Training Accuracy=0.273438, Top-5 Accuracy=0.593750, lr=0.010000
# Iter=51328/epoch=0, Loss=2.924370, Training Accuracy=0.210938, Top-5 Accuracy=0.539062, lr=0.010000
# Iter=61568/epoch=0, Loss=2.738273, Training Accuracy=0.250000, Top-5 Accuracy=0.593750, lr=0.010000
# Iter=71808/epoch=1, Loss=2.637282, Training Accuracy=0.218750, Top-5 Accuracy=0.664062, lr=0.010000
# Iter=82048/epoch=1, Loss=2.514938, Training Accuracy=0.343750, Top-5 Accuracy=0.671875, lr=0.010000
# Iter=92288/epoch=1, Loss=2.937839, Training Accuracy=0.140625, Top-5 Accuracy=0.539062, lr=0.010000
# Iter=102528/epoch=1, Loss=2.589881, Training Accuracy=0.312500, Top-5 Accuracy=0.632812, lr=0.010000
#
# Iter=102528/epoch=1, Validation Accuracy=0.104167
# Iter=112768/epoch=1, Loss=2.694406, Training Accuracy=0.273438, Top-5 Accuracy=0.664062, lr=0.010000
# Iter=123008/epoch=1, Loss=2.523404, Training Accuracy=0.257812, Top-5 Accuracy=0.679688, lr=0.010000
# Iter=133248/epoch=2, Loss=2.713919, Training Accuracy=0.289062, Top-5 Accuracy=0.585938, lr=0.010000
# Iter=143488/epoch=2, Loss=2.370452, Training Accuracy=0.304688, Top-5 Accuracy=0.656250, lr=0.010000
# Iter=153728/epoch=2, Loss=2.207539, Training Accuracy=0.359375, Top-5 Accuracy=0.742188, lr=0.010000
# Iter=163968/epoch=2, Loss=2.222386, Training Accuracy=0.359375, Top-5 Accuracy=0.726562, lr=0.010000
# Iter=174208/epoch=2, Loss=2.262640, Training Accuracy=0.335938, Top-5 Accuracy=0.640625, lr=0.010000
# Iter=184448/epoch=2, Loss=2.219111, Training Accuracy=0.429688, Top-5 Accuracy=0.718750, lr=0.010000
# Iter=194688/epoch=3, Loss=1.995909, Training Accuracy=0.406250, Top-5 Accuracy=0.804688, lr=0.010000
# Iter=204928/epoch=3, Loss=1.850755, Training Accuracy=0.445312, Top-5 Accuracy=0.789062, lr=0.010000
#
# Iter=204928/epoch=3, Validation Accuracy=0.247396
# Iter=215168/epoch=3, Loss=2.075957, Training Accuracy=0.406250, Top-5 Accuracy=0.750000, lr=0.010000
# Iter=225408/epoch=3, Loss=2.022425, Training Accuracy=0.445312, Top-5 Accuracy=0.773438, lr=0.010000
# Iter=235648/epoch=3, Loss=1.916503, Training Accuracy=0.453125, Top-5 Accuracy=0.828125, lr=0.010000
# Iter=245888/epoch=3, Loss=1.755819, Training Accuracy=0.492188, Top-5 Accuracy=0.828125, lr=0.010000
# Iter=256128/epoch=4, Loss=1.594486, Training Accuracy=0.500000, Top-5 Accuracy=0.875000, lr=0.010000
# Iter=266368/epoch=4, Loss=1.715263, Training Accuracy=0.507812, Top-5 Accuracy=0.820312, lr=0.010000
# Iter=276608/epoch=4, Loss=1.683702, Training Accuracy=0.468750, Top-5 Accuracy=0.875000, lr=0.010000
# Iter=286848/epoch=4, Loss=1.877711, Training Accuracy=0.406250, Top-5 Accuracy=0.828125, lr=0.010000
# Iter=297088/epoch=4, Loss=1.473271, Training Accuracy=0.609375, Top-5 Accuracy=0.898438, lr=0.010000
# Iter=307328/epoch=4, Loss=1.555617, Training Accuracy=0.531250, Top-5 Accuracy=0.835938, lr=0.010000
#
# Iter=307328/epoch=4, Validation Accuracy=0.299479
# Iter=317568/epoch=5, Loss=1.474986, Training Accuracy=0.578125, Top-5 Accuracy=0.875000, lr=0.010000
# Iter=327808/epoch=5, Loss=1.536424, Training Accuracy=0.523438, Top-5 Accuracy=0.859375, lr=0.010000
# Iter=338048/epoch=5, Loss=1.541471, Training Accuracy=0.578125, Top-5 Accuracy=0.851562, lr=0.010000
# Iter=348288/epoch=5, Loss=1.542686, Training Accuracy=0.476562, Top-5 Accuracy=0.859375, lr=0.010000
# Iter=358528/epoch=5, Loss=1.721405, Training Accuracy=0.546875, Top-5 Accuracy=0.820312, lr=0.010000
# Iter=368768/epoch=5, Loss=1.303005, Training Accuracy=0.578125, Top-5 Accuracy=0.875000, lr=0.010000
# Iter=379008/epoch=5, Loss=1.454058, Training Accuracy=0.570312, Top-5 Accuracy=0.882812, lr=0.010000
# Iter=389248/epoch=6, Loss=1.128430, Training Accuracy=0.664062, Top-5 Accuracy=0.914062, lr=0.010000
# Iter=399488/epoch=6, Loss=1.228999, Training Accuracy=0.617188, Top-5 Accuracy=0.914062, lr=0.010000
# Iter=409728/epoch=6, Loss=1.547617, Training Accuracy=0.546875, Top-5 Accuracy=0.867188, lr=0.010000
#
# Iter=409728/epoch=6, Validation Accuracy=0.510417
# Iter=419968/epoch=6, Loss=1.303472, Training Accuracy=0.554688, Top-5 Accuracy=0.914062, lr=0.010000
# Iter=430208/epoch=6, Loss=1.520955, Training Accuracy=0.539062, Top-5 Accuracy=0.875000, lr=0.010000
# Iter=440448/epoch=6, Loss=1.194885, Training Accuracy=0.578125, Top-5 Accuracy=0.898438, lr=0.010000
# Iter=450688/epoch=7, Loss=0.998673, Training Accuracy=0.687500, Top-5 Accuracy=0.945312, lr=0.010000
# Iter=460928/epoch=7, Loss=1.101532, Training Accuracy=0.640625, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=471168/epoch=7, Loss=1.134992, Training Accuracy=0.687500, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=481408/epoch=7, Loss=1.080236, Training Accuracy=0.687500, Top-5 Accuracy=0.906250, lr=0.010000
# Iter=491648/epoch=7, Loss=1.281136, Training Accuracy=0.617188, Top-5 Accuracy=0.898438, lr=0.010000
# Iter=501888/epoch=7, Loss=0.994054, Training Accuracy=0.695312, Top-5 Accuracy=0.921875, lr=0.010000
# Iter=512128/epoch=8, Loss=1.199010, Training Accuracy=0.585938, Top-5 Accuracy=0.929688, lr=0.010000
#
# Iter=512128/epoch=8, Validation Accuracy=0.406250
# Iter=522368/epoch=8, Loss=1.316560, Training Accuracy=0.609375, Top-5 Accuracy=0.875000, lr=0.010000
# Iter=532608/epoch=8, Loss=1.226592, Training Accuracy=0.664062, Top-5 Accuracy=0.898438, lr=0.010000
# Iter=542848/epoch=8, Loss=1.059001, Training Accuracy=0.625000, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=553088/epoch=8, Loss=1.189413, Training Accuracy=0.664062, Top-5 Accuracy=0.906250, lr=0.010000
# Iter=563328/epoch=8, Loss=1.116143, Training Accuracy=0.664062, Top-5 Accuracy=0.929688, lr=0.010000
# Iter=573568/epoch=9, Loss=0.981526, Training Accuracy=0.625000, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=583808/epoch=9, Loss=1.200202, Training Accuracy=0.601562, Top-5 Accuracy=0.929688, lr=0.010000
# Iter=594048/epoch=9, Loss=0.998773, Training Accuracy=0.640625, Top-5 Accuracy=0.945312, lr=0.010000
# Iter=604288/epoch=9, Loss=1.039387, Training Accuracy=0.656250, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=614528/epoch=9, Loss=1.025625, Training Accuracy=0.687500, Top-5 Accuracy=0.914062, lr=0.010000
#
# Iter=614528/epoch=9, Validation Accuracy=0.466146
# Iter=624768/epoch=9, Loss=1.232802, Training Accuracy=0.609375, Top-5 Accuracy=0.929688, lr=0.010000
# Iter=635008/epoch=10, Loss=1.061851, Training Accuracy=0.695312, Top-5 Accuracy=0.929688, lr=0.010000
# Iter=645248/epoch=10, Loss=0.851634, Training Accuracy=0.742188, Top-5 Accuracy=0.953125, lr=0.010000
# Iter=655488/epoch=10, Loss=1.273110, Training Accuracy=0.648438, Top-5 Accuracy=0.898438, lr=0.010000
# Iter=665728/epoch=10, Loss=0.991372, Training Accuracy=0.679688, Top-5 Accuracy=0.953125, lr=0.010000
# Iter=675968/epoch=10, Loss=0.855362, Training Accuracy=0.671875, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=686208/epoch=10, Loss=0.772543, Training Accuracy=0.765625, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=696448/epoch=10, Loss=1.063314, Training Accuracy=0.664062, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=706688/epoch=11, Loss=0.819417, Training Accuracy=0.718750, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=716928/epoch=11, Loss=0.912880, Training Accuracy=0.710938, Top-5 Accuracy=0.937500, lr=0.010000
#
# Iter=716928/epoch=11, Validation Accuracy=0.479167
# Iter=727168/epoch=11, Loss=0.971429, Training Accuracy=0.703125, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=737408/epoch=11, Loss=0.928220, Training Accuracy=0.664062, Top-5 Accuracy=0.945312, lr=0.010000
# Iter=747648/epoch=11, Loss=0.860918, Training Accuracy=0.750000, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=757888/epoch=11, Loss=0.725950, Training Accuracy=0.812500, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=768128/epoch=12, Loss=0.880068, Training Accuracy=0.750000, Top-5 Accuracy=0.929688, lr=0.010000
# Iter=778368/epoch=12, Loss=0.754085, Training Accuracy=0.781250, Top-5 Accuracy=0.945312, lr=0.010000
# Iter=788608/epoch=12, Loss=0.724897, Training Accuracy=0.796875, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=798848/epoch=12, Loss=0.772713, Training Accuracy=0.742188, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=809088/epoch=12, Loss=0.872556, Training Accuracy=0.703125, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=819328/epoch=12, Loss=0.600610, Training Accuracy=0.757812, Top-5 Accuracy=0.976562, lr=0.010000
#
# Iter=819328/epoch=12, Validation Accuracy=0.593750
# Iter=829568/epoch=13, Loss=0.789057, Training Accuracy=0.757812, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=839808/epoch=13, Loss=0.824783, Training Accuracy=0.757812, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=850048/epoch=13, Loss=0.831608, Training Accuracy=0.765625, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=860288/epoch=13, Loss=0.949070, Training Accuracy=0.726562, Top-5 Accuracy=0.937500, lr=0.010000
# Iter=870528/epoch=13, Loss=0.637648, Training Accuracy=0.750000, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=880768/epoch=13, Loss=0.618994, Training Accuracy=0.843750, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=891008/epoch=14, Loss=0.845408, Training Accuracy=0.710938, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=901248/epoch=14, Loss=0.732087, Training Accuracy=0.757812, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=911488/epoch=14, Loss=0.797955, Training Accuracy=0.781250, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=921728/epoch=14, Loss=0.691440, Training Accuracy=0.773438, Top-5 Accuracy=0.968750, lr=0.010000
#
# Iter=921728/epoch=14, Validation Accuracy=0.588542
# Iter=931968/epoch=14, Loss=0.839439, Training Accuracy=0.742188, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=942208/epoch=14, Loss=0.650976, Training Accuracy=0.789062, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=952448/epoch=15, Loss=0.612420, Training Accuracy=0.796875, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=962688/epoch=15, Loss=0.804219, Training Accuracy=0.750000, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=972928/epoch=15, Loss=0.837844, Training Accuracy=0.710938, Top-5 Accuracy=0.953125, lr=0.010000
# Iter=983168/epoch=15, Loss=0.764935, Training Accuracy=0.757812, Top-5 Accuracy=0.945312, lr=0.010000
# Iter=993408/epoch=15, Loss=0.586558, Training Accuracy=0.820312, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1003648/epoch=15, Loss=0.413203, Training Accuracy=0.859375, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1013888/epoch=16, Loss=0.659487, Training Accuracy=0.734375, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1024128/epoch=16, Loss=0.591924, Training Accuracy=0.804688, Top-5 Accuracy=0.960938, lr=0.010000
#
# Iter=1024128/epoch=16, Validation Accuracy=0.559896
# Iter=1034368/epoch=16, Loss=0.679402, Training Accuracy=0.828125, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=1044608/epoch=16, Loss=0.744768, Training Accuracy=0.781250, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=1054848/epoch=16, Loss=0.477623, Training Accuracy=0.828125, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1065088/epoch=16, Loss=0.556656, Training Accuracy=0.796875, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=1075328/epoch=16, Loss=0.510646, Training Accuracy=0.789062, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1085568/epoch=17, Loss=0.492088, Training Accuracy=0.851562, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1095808/epoch=17, Loss=0.672017, Training Accuracy=0.742188, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1106048/epoch=17, Loss=0.558501, Training Accuracy=0.828125, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=1116288/epoch=17, Loss=0.706288, Training Accuracy=0.796875, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=1126528/epoch=17, Loss=0.573758, Training Accuracy=0.781250, Top-5 Accuracy=0.992188, lr=0.010000
#
# Iter=1126528/epoch=17, Validation Accuracy=0.627604
# Iter=1136768/epoch=17, Loss=0.588301, Training Accuracy=0.757812, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=1147008/epoch=18, Loss=0.384200, Training Accuracy=0.882812, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1157248/epoch=18, Loss=0.660442, Training Accuracy=0.773438, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1167488/epoch=18, Loss=0.577176, Training Accuracy=0.812500, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1177728/epoch=18, Loss=0.506328, Training Accuracy=0.828125, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=1187968/epoch=18, Loss=0.667646, Training Accuracy=0.750000, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=1198208/epoch=18, Loss=0.593783, Training Accuracy=0.828125, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=1208448/epoch=19, Loss=0.657129, Training Accuracy=0.796875, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1218688/epoch=19, Loss=0.490591, Training Accuracy=0.843750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1228928/epoch=19, Loss=0.637253, Training Accuracy=0.781250, Top-5 Accuracy=0.976562, lr=0.010000
#
# Iter=1228928/epoch=19, Validation Accuracy=0.601562
# Iter=1239168/epoch=19, Loss=0.593401, Training Accuracy=0.734375, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1249408/epoch=19, Loss=0.690743, Training Accuracy=0.789062, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=1259648/epoch=19, Loss=0.497361, Training Accuracy=0.851562, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1269888/epoch=20, Loss=0.403773, Training Accuracy=0.898438, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=1280128/epoch=20, Loss=0.395035, Training Accuracy=0.851562, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1290368/epoch=20, Loss=0.416654, Training Accuracy=0.843750, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1300608/epoch=20, Loss=0.456386, Training Accuracy=0.851562, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1310848/epoch=20, Loss=0.624902, Training Accuracy=0.789062, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1321088/epoch=20, Loss=0.519236, Training Accuracy=0.859375, Top-5 Accuracy=0.968750, lr=0.010000
# Iter=1331328/epoch=21, Loss=0.376003, Training Accuracy=0.820312, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=1331328/epoch=21, Validation Accuracy=0.578125
# Iter=1341568/epoch=21, Loss=0.516695, Training Accuracy=0.828125, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1351808/epoch=21, Loss=0.440143, Training Accuracy=0.835938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1362048/epoch=21, Loss=0.384554, Training Accuracy=0.867188, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1372288/epoch=21, Loss=0.493727, Training Accuracy=0.843750, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=1382528/epoch=21, Loss=0.313191, Training Accuracy=0.898438, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1392768/epoch=21, Loss=0.353337, Training Accuracy=0.875000, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1403008/epoch=22, Loss=0.455641, Training Accuracy=0.828125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1413248/epoch=22, Loss=0.623924, Training Accuracy=0.789062, Top-5 Accuracy=0.960938, lr=0.010000
# Iter=1423488/epoch=22, Loss=0.523795, Training Accuracy=0.820312, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1433728/epoch=22, Loss=0.637374, Training Accuracy=0.773438, Top-5 Accuracy=0.976562, lr=0.010000
#
# Iter=1433728/epoch=22, Validation Accuracy=0.578125
# Iter=1443968/epoch=22, Loss=0.371003, Training Accuracy=0.835938, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1454208/epoch=22, Loss=0.506236, Training Accuracy=0.820312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1464448/epoch=23, Loss=0.382137, Training Accuracy=0.882812, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1474688/epoch=23, Loss=0.411103, Training Accuracy=0.867188, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1484928/epoch=23, Loss=0.346305, Training Accuracy=0.859375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1495168/epoch=23, Loss=0.546810, Training Accuracy=0.835938, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=1505408/epoch=23, Loss=0.313138, Training Accuracy=0.859375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1515648/epoch=23, Loss=0.371880, Training Accuracy=0.859375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1525888/epoch=24, Loss=0.299840, Training Accuracy=0.937500, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1536128/epoch=24, Loss=0.446656, Training Accuracy=0.867188, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=1536128/epoch=24, Validation Accuracy=0.572917
# Iter=1546368/epoch=24, Loss=0.377377, Training Accuracy=0.859375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1556608/epoch=24, Loss=0.345470, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1566848/epoch=24, Loss=0.310983, Training Accuracy=0.875000, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1577088/epoch=24, Loss=0.372361, Training Accuracy=0.890625, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1587328/epoch=25, Loss=0.347069, Training Accuracy=0.882812, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1597568/epoch=25, Loss=0.294069, Training Accuracy=0.898438, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1607808/epoch=25, Loss=0.321350, Training Accuracy=0.859375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1618048/epoch=25, Loss=0.246435, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1628288/epoch=25, Loss=0.193561, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1638528/epoch=25, Loss=0.293318, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=1638528/epoch=25, Validation Accuracy=0.559896
# Iter=1648768/epoch=26, Loss=0.283152, Training Accuracy=0.882812, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1659008/epoch=26, Loss=0.283801, Training Accuracy=0.914062, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1669248/epoch=26, Loss=0.264690, Training Accuracy=0.921875, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1679488/epoch=26, Loss=0.355888, Training Accuracy=0.867188, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1689728/epoch=26, Loss=0.283166, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1699968/epoch=26, Loss=0.487523, Training Accuracy=0.812500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1710208/epoch=27, Loss=0.251506, Training Accuracy=0.898438, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1720448/epoch=27, Loss=0.340307, Training Accuracy=0.890625, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1730688/epoch=27, Loss=0.327105, Training Accuracy=0.859375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1740928/epoch=27, Loss=0.274020, Training Accuracy=0.914062, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=1740928/epoch=27, Validation Accuracy=0.601562
# Iter=1751168/epoch=27, Loss=0.174686, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1761408/epoch=27, Loss=0.235132, Training Accuracy=0.898438, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1771648/epoch=27, Loss=0.255057, Training Accuracy=0.882812, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1781888/epoch=28, Loss=0.343611, Training Accuracy=0.882812, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=1792128/epoch=28, Loss=0.372765, Training Accuracy=0.867188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1802368/epoch=28, Loss=0.142132, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1812608/epoch=28, Loss=0.299327, Training Accuracy=0.898438, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1822848/epoch=28, Loss=0.269313, Training Accuracy=0.906250, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1833088/epoch=28, Loss=0.344517, Training Accuracy=0.882812, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1843328/epoch=29, Loss=0.164729, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=1843328/epoch=29, Validation Accuracy=0.627604
# Iter=1853568/epoch=29, Loss=0.309317, Training Accuracy=0.867188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1863808/epoch=29, Loss=0.340708, Training Accuracy=0.859375, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1874048/epoch=29, Loss=0.515603, Training Accuracy=0.859375, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1884288/epoch=29, Loss=0.244285, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1894528/epoch=29, Loss=0.285155, Training Accuracy=0.906250, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1904768/epoch=30, Loss=0.240409, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1915008/epoch=30, Loss=0.342704, Training Accuracy=0.867188, Top-5 Accuracy=1.000000, lr=0.010000
# Model saved in file at iteration 1920128: ./tf_resnet_model_iter15001.ckpt
# Iter=1925248/epoch=30, Loss=0.462061, Training Accuracy=0.875000, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=1935488/epoch=30, Loss=0.298657, Training Accuracy=0.867188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1945728/epoch=30, Loss=0.182374, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=1945728/epoch=30, Validation Accuracy=0.671875
# Iter=1955968/epoch=30, Loss=0.268535, Training Accuracy=0.914062, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1966208/epoch=31, Loss=0.181425, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1976448/epoch=31, Loss=0.280025, Training Accuracy=0.890625, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1986688/epoch=31, Loss=0.266818, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=1996928/epoch=31, Loss=0.349419, Training Accuracy=0.875000, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2007168/epoch=31, Loss=0.193316, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2017408/epoch=31, Loss=0.218783, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2027648/epoch=32, Loss=0.203495, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2037888/epoch=32, Loss=0.333368, Training Accuracy=0.914062, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=2048128/epoch=32, Loss=0.348037, Training Accuracy=0.882812, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2048128/epoch=32, Validation Accuracy=0.609375
# Iter=2058368/epoch=32, Loss=0.363378, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2068608/epoch=32, Loss=0.099399, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2078848/epoch=32, Loss=0.198312, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2089088/epoch=32, Loss=0.174450, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2099328/epoch=33, Loss=0.220188, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2109568/epoch=33, Loss=0.294692, Training Accuracy=0.890625, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=2119808/epoch=33, Loss=0.331371, Training Accuracy=0.882812, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2130048/epoch=33, Loss=0.073905, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2140288/epoch=33, Loss=0.167516, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2150528/epoch=33, Loss=0.255733, Training Accuracy=0.914062, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2150528/epoch=33, Validation Accuracy=0.611979
# Iter=2160768/epoch=34, Loss=0.215132, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2171008/epoch=34, Loss=0.284456, Training Accuracy=0.898438, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2181248/epoch=34, Loss=0.195800, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2191488/epoch=34, Loss=0.195173, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2201728/epoch=34, Loss=0.188522, Training Accuracy=0.945312, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=2211968/epoch=34, Loss=0.208168, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2222208/epoch=35, Loss=0.244860, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2232448/epoch=35, Loss=0.256749, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2242688/epoch=35, Loss=0.171586, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2252928/epoch=35, Loss=0.203110, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2252928/epoch=35, Validation Accuracy=0.614583
# Iter=2263168/epoch=35, Loss=0.078835, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2273408/epoch=35, Loss=0.248044, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2283648/epoch=36, Loss=0.226992, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2293888/epoch=36, Loss=0.220345, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2304128/epoch=36, Loss=0.218926, Training Accuracy=0.898438, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2314368/epoch=36, Loss=0.235518, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2324608/epoch=36, Loss=0.105465, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2334848/epoch=36, Loss=0.136431, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2345088/epoch=37, Loss=0.109375, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2355328/epoch=37, Loss=0.117358, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2355328/epoch=37, Validation Accuracy=0.638021
# Iter=2365568/epoch=37, Loss=0.300371, Training Accuracy=0.882812, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2375808/epoch=37, Loss=0.152329, Training Accuracy=0.945312, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=2386048/epoch=37, Loss=0.166842, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2396288/epoch=37, Loss=0.252742, Training Accuracy=0.914062, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=2406528/epoch=38, Loss=0.311077, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2416768/epoch=38, Loss=0.139928, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2427008/epoch=38, Loss=0.192345, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2437248/epoch=38, Loss=0.288494, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2447488/epoch=38, Loss=0.197173, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2457728/epoch=38, Loss=0.112711, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2457728/epoch=38, Validation Accuracy=0.658854
# Iter=2467968/epoch=38, Loss=0.190987, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2478208/epoch=39, Loss=0.209415, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2488448/epoch=39, Loss=0.097428, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2498688/epoch=39, Loss=0.092538, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2508928/epoch=39, Loss=0.264733, Training Accuracy=0.921875, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=2519168/epoch=39, Loss=0.181284, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2529408/epoch=39, Loss=0.190735, Training Accuracy=0.906250, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2539648/epoch=40, Loss=0.248343, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2549888/epoch=40, Loss=0.302888, Training Accuracy=0.898438, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2560128/epoch=40, Loss=0.216309, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2560128/epoch=40, Validation Accuracy=0.609375
# Iter=2570368/epoch=40, Loss=0.280964, Training Accuracy=0.945312, Top-5 Accuracy=0.984375, lr=0.010000
# Iter=2580608/epoch=40, Loss=0.116731, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2590848/epoch=40, Loss=0.136217, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2601088/epoch=41, Loss=0.156834, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2611328/epoch=41, Loss=0.222256, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2621568/epoch=41, Loss=0.127160, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2631808/epoch=41, Loss=0.074675, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2642048/epoch=41, Loss=0.080884, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2652288/epoch=41, Loss=0.135622, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2662528/epoch=42, Loss=0.184777, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2662528/epoch=42, Validation Accuracy=0.648438
# Iter=2672768/epoch=42, Loss=0.226977, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2683008/epoch=42, Loss=0.139140, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2693248/epoch=42, Loss=0.131462, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2703488/epoch=42, Loss=0.285676, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2713728/epoch=42, Loss=0.120764, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2723968/epoch=43, Loss=0.208009, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2734208/epoch=43, Loss=0.066341, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2744448/epoch=43, Loss=0.167182, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2754688/epoch=43, Loss=0.161336, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2764928/epoch=43, Loss=0.050861, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2764928/epoch=43, Validation Accuracy=0.661458
# Iter=2775168/epoch=43, Loss=0.192591, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2785408/epoch=43, Loss=0.155557, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2795648/epoch=44, Loss=0.082599, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2805888/epoch=44, Loss=0.135500, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2816128/epoch=44, Loss=0.089240, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2826368/epoch=44, Loss=0.146164, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2836608/epoch=44, Loss=0.166444, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2846848/epoch=44, Loss=0.156602, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2857088/epoch=45, Loss=0.201851, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2867328/epoch=45, Loss=0.127864, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2867328/epoch=45, Validation Accuracy=0.648438
# Iter=2877568/epoch=45, Loss=0.179002, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2887808/epoch=45, Loss=0.099496, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2898048/epoch=45, Loss=0.165936, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2908288/epoch=45, Loss=0.072761, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2918528/epoch=46, Loss=0.156828, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2928768/epoch=46, Loss=0.104346, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2939008/epoch=46, Loss=0.122107, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2949248/epoch=46, Loss=0.128344, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2959488/epoch=46, Loss=0.090759, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2969728/epoch=46, Loss=0.277113, Training Accuracy=0.929688, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=2969728/epoch=46, Validation Accuracy=0.635417
# Iter=2979968/epoch=47, Loss=0.233586, Training Accuracy=0.914062, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=2990208/epoch=47, Loss=0.074517, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3000448/epoch=47, Loss=0.142718, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3010688/epoch=47, Loss=0.121301, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3020928/epoch=47, Loss=0.081363, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3031168/epoch=47, Loss=0.074876, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3041408/epoch=48, Loss=0.132177, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3051648/epoch=48, Loss=0.129551, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3061888/epoch=48, Loss=0.039638, Training Accuracy=1.000000, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3072128/epoch=48, Loss=0.099404, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3072128/epoch=48, Validation Accuracy=0.619792
# Iter=3082368/epoch=48, Loss=0.146244, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3092608/epoch=48, Loss=0.197306, Training Accuracy=0.953125, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=3102848/epoch=48, Loss=0.108493, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3113088/epoch=49, Loss=0.111883, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3123328/epoch=49, Loss=0.152767, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3133568/epoch=49, Loss=0.111747, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3143808/epoch=49, Loss=0.134716, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3154048/epoch=49, Loss=0.127894, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3164288/epoch=49, Loss=0.087186, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3174528/epoch=50, Loss=0.133769, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3174528/epoch=50, Validation Accuracy=0.617188
# Iter=3184768/epoch=50, Loss=0.185764, Training Accuracy=0.914062, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3195008/epoch=50, Loss=0.158314, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3205248/epoch=50, Loss=0.124585, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3215488/epoch=50, Loss=0.111816, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3225728/epoch=50, Loss=0.247587, Training Accuracy=0.960938, Top-5 Accuracy=0.976562, lr=0.010000
# Iter=3235968/epoch=51, Loss=0.235792, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3246208/epoch=51, Loss=0.123119, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3256448/epoch=51, Loss=0.090499, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3266688/epoch=51, Loss=0.074340, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3276928/epoch=51, Loss=0.167838, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3276928/epoch=51, Validation Accuracy=0.565104
# Iter=3287168/epoch=51, Loss=0.232051, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3297408/epoch=52, Loss=0.125178, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3307648/epoch=52, Loss=0.203774, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3317888/epoch=52, Loss=0.104697, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3328128/epoch=52, Loss=0.118787, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3338368/epoch=52, Loss=0.088376, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3348608/epoch=52, Loss=0.105633, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3358848/epoch=53, Loss=0.273964, Training Accuracy=0.914062, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=3369088/epoch=53, Loss=0.106921, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3379328/epoch=53, Loss=0.144751, Training Accuracy=0.968750, Top-5 Accuracy=0.992188, lr=0.010000
#
# Iter=3379328/epoch=53, Validation Accuracy=0.630208
# Iter=3389568/epoch=53, Loss=0.184858, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3399808/epoch=53, Loss=0.085191, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3410048/epoch=53, Loss=0.084520, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3420288/epoch=54, Loss=0.081140, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3430528/epoch=54, Loss=0.059167, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3440768/epoch=54, Loss=0.045668, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3451008/epoch=54, Loss=0.218887, Training Accuracy=0.960938, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=3461248/epoch=54, Loss=0.073119, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3471488/epoch=54, Loss=0.134600, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3481728/epoch=54, Loss=0.087456, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3481728/epoch=54, Validation Accuracy=0.611979
# Iter=3491968/epoch=55, Loss=0.155630, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3502208/epoch=55, Loss=0.151017, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3512448/epoch=55, Loss=0.119151, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3522688/epoch=55, Loss=0.082159, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3532928/epoch=55, Loss=0.172552, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3543168/epoch=55, Loss=0.132716, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3553408/epoch=56, Loss=0.106778, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3563648/epoch=56, Loss=0.239515, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3573888/epoch=56, Loss=0.118909, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3584128/epoch=56, Loss=0.105339, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3584128/epoch=56, Validation Accuracy=0.601562
# Iter=3594368/epoch=56, Loss=0.131238, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3604608/epoch=56, Loss=0.255809, Training Accuracy=0.921875, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3614848/epoch=57, Loss=0.140527, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3625088/epoch=57, Loss=0.076897, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3635328/epoch=57, Loss=0.104349, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3645568/epoch=57, Loss=0.136507, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3655808/epoch=57, Loss=0.070206, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3666048/epoch=57, Loss=0.070733, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3676288/epoch=58, Loss=0.213289, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3686528/epoch=58, Loss=0.091314, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3686528/epoch=58, Validation Accuracy=0.638021
# Iter=3696768/epoch=58, Loss=0.082310, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3707008/epoch=58, Loss=0.128728, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3717248/epoch=58, Loss=0.071273, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3727488/epoch=58, Loss=0.076827, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3737728/epoch=59, Loss=0.136263, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3747968/epoch=59, Loss=0.131866, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3758208/epoch=59, Loss=0.061112, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3768448/epoch=59, Loss=0.126729, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3778688/epoch=59, Loss=0.109114, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3788928/epoch=59, Loss=0.072207, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3788928/epoch=59, Validation Accuracy=0.658854
# Iter=3799168/epoch=59, Loss=0.061361, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3809408/epoch=60, Loss=0.218322, Training Accuracy=0.914062, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3819648/epoch=60, Loss=0.032177, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3829888/epoch=60, Loss=0.059076, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Model saved in file at iteration 3840128: ./tf_resnet_model_iter30001.ckpt
# Iter=3840128/epoch=60, Loss=0.138936, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3850368/epoch=60, Loss=0.162674, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3860608/epoch=60, Loss=0.151821, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3870848/epoch=61, Loss=0.158571, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3881088/epoch=61, Loss=0.184700, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3891328/epoch=61, Loss=0.111852, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3891328/epoch=61, Validation Accuracy=0.682292
# Iter=3901568/epoch=61, Loss=0.051475, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3911808/epoch=61, Loss=0.132264, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3922048/epoch=61, Loss=0.131333, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3932288/epoch=62, Loss=0.090305, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3942528/epoch=62, Loss=0.076567, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3952768/epoch=62, Loss=0.133658, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3963008/epoch=62, Loss=0.059189, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3973248/epoch=62, Loss=0.120890, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3983488/epoch=62, Loss=0.065086, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=3993728/epoch=63, Loss=0.057685, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=3993728/epoch=63, Validation Accuracy=0.687500
# Iter=4003968/epoch=63, Loss=0.115629, Training Accuracy=0.968750, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=4014208/epoch=63, Loss=0.121311, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4024448/epoch=63, Loss=0.090986, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4034688/epoch=63, Loss=0.140092, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4044928/epoch=63, Loss=0.094095, Training Accuracy=0.976562, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=4055168/epoch=64, Loss=0.027160, Training Accuracy=1.000000, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4065408/epoch=64, Loss=0.098509, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4075648/epoch=64, Loss=0.129078, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4085888/epoch=64, Loss=0.140557, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4096128/epoch=64, Loss=0.155782, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=4096128/epoch=64, Validation Accuracy=0.627604
# Iter=4106368/epoch=64, Loss=0.135407, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4116608/epoch=65, Loss=0.065499, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4126848/epoch=65, Loss=0.094898, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4137088/epoch=65, Loss=0.149731, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4147328/epoch=65, Loss=0.060374, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4157568/epoch=65, Loss=0.113460, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4167808/epoch=65, Loss=0.163812, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4178048/epoch=65, Loss=0.136116, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4188288/epoch=66, Loss=0.117780, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4198528/epoch=66, Loss=0.038354, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=4198528/epoch=66, Validation Accuracy=0.606771
# Iter=4208768/epoch=66, Loss=0.088266, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4219008/epoch=66, Loss=0.066499, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4229248/epoch=66, Loss=0.088899, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4239488/epoch=66, Loss=0.137276, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4249728/epoch=67, Loss=0.088113, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4259968/epoch=67, Loss=0.082304, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4270208/epoch=67, Loss=0.056224, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4280448/epoch=67, Loss=0.033163, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4290688/epoch=67, Loss=0.107911, Training Accuracy=0.976562, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=4300928/epoch=67, Loss=0.164800, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=4300928/epoch=67, Validation Accuracy=0.643229
# Iter=4311168/epoch=68, Loss=0.123805, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4321408/epoch=68, Loss=0.093653, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4331648/epoch=68, Loss=0.044091, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4341888/epoch=68, Loss=0.167659, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4352128/epoch=68, Loss=0.098614, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4362368/epoch=68, Loss=0.035863, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4372608/epoch=69, Loss=0.106066, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4382848/epoch=69, Loss=0.111723, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4393088/epoch=69, Loss=0.172486, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4403328/epoch=69, Loss=0.111373, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=4403328/epoch=69, Validation Accuracy=0.604167
# Iter=4413568/epoch=69, Loss=0.082646, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4423808/epoch=69, Loss=0.159091, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4434048/epoch=70, Loss=0.149099, Training Accuracy=0.960938, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=4444288/epoch=70, Loss=0.070410, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4454528/epoch=70, Loss=0.022900, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4464768/epoch=70, Loss=0.075725, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4475008/epoch=70, Loss=0.075029, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4485248/epoch=70, Loss=0.118299, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4495488/epoch=70, Loss=0.074137, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4505728/epoch=71, Loss=0.053187, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=4505728/epoch=71, Validation Accuracy=0.682292
# Iter=4515968/epoch=71, Loss=0.123762, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4526208/epoch=71, Loss=0.056431, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4536448/epoch=71, Loss=0.041900, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# ...
# Iter=4843648/epoch=76, Loss=0.052581, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4853888/epoch=76, Loss=0.194185, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4864128/epoch=76, Loss=0.063205, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4874368/epoch=76, Loss=0.145717, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4884608/epoch=77, Loss=0.026599, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4894848/epoch=77, Loss=0.139824, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4905088/epoch=77, Loss=0.102089, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4915328/epoch=77, Loss=0.174432, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=4915328/epoch=77, Validation Accuracy=0.658854
# Iter=4925568/epoch=77, Loss=0.029275, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4935808/epoch=77, Loss=0.094253, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4946048/epoch=78, Loss=0.125861, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4956288/epoch=78, Loss=0.033878, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4966528/epoch=78, Loss=0.101945, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4976768/epoch=78, Loss=0.092578, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4987008/epoch=78, Loss=0.056121, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=4997248/epoch=78, Loss=0.044276, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5007488/epoch=79, Loss=0.010703, Training Accuracy=1.000000, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5017728/epoch=79, Loss=0.092214, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5017728/epoch=79, Validation Accuracy=0.651042
# Iter=5027968/epoch=79, Loss=0.093714, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5038208/epoch=79, Loss=0.037647, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5048448/epoch=79, Loss=0.153634, Training Accuracy=0.960938, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=5058688/epoch=79, Loss=0.105966, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5068928/epoch=80, Loss=0.097468, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5079168/epoch=80, Loss=0.057763, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5089408/epoch=80, Loss=0.089025, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5099648/epoch=80, Loss=0.076160, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5109888/epoch=80, Loss=0.091081, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5120128/epoch=80, Loss=0.079025, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5120128/epoch=80, Validation Accuracy=0.598958
# Iter=5130368/epoch=81, Loss=0.125365, Training Accuracy=0.960938, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=5140608/epoch=81, Loss=0.112920, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5150848/epoch=81, Loss=0.058946, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5161088/epoch=81, Loss=0.065787, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5171328/epoch=81, Loss=0.091928, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5181568/epoch=81, Loss=0.047458, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5191808/epoch=81, Loss=0.157532, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5202048/epoch=82, Loss=0.079983, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5212288/epoch=82, Loss=0.081793, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5222528/epoch=82, Loss=0.081387, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5222528/epoch=82, Validation Accuracy=0.666667
# Iter=5232768/epoch=82, Loss=0.097395, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5243008/epoch=82, Loss=0.130524, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5253248/epoch=82, Loss=0.061158, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5263488/epoch=83, Loss=0.025093, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5273728/epoch=83, Loss=0.050892, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5283968/epoch=83, Loss=0.034360, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5294208/epoch=83, Loss=0.107689, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5304448/epoch=83, Loss=0.106037, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5314688/epoch=83, Loss=0.014676, Training Accuracy=1.000000, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5324928/epoch=84, Loss=0.104157, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5324928/epoch=84, Validation Accuracy=0.669271
# Iter=5335168/epoch=84, Loss=0.065765, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5345408/epoch=84, Loss=0.089417, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5355648/epoch=84, Loss=0.056131, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5365888/epoch=84, Loss=0.122660, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5376128/epoch=84, Loss=0.099292, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5386368/epoch=85, Loss=0.152462, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5396608/epoch=85, Loss=0.094145, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5406848/epoch=85, Loss=0.150943, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5417088/epoch=85, Loss=0.117073, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5427328/epoch=85, Loss=0.060220, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5427328/epoch=85, Validation Accuracy=0.632812
# Iter=5437568/epoch=85, Loss=0.050746, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5447808/epoch=86, Loss=0.035672, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5458048/epoch=86, Loss=0.049412, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5468288/epoch=86, Loss=0.070165, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5478528/epoch=86, Loss=0.071339, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5488768/epoch=86, Loss=0.117794, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5499008/epoch=86, Loss=0.111839, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5509248/epoch=86, Loss=0.139558, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5519488/epoch=87, Loss=0.116811, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5529728/epoch=87, Loss=0.078853, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5529728/epoch=87, Validation Accuracy=0.674479
# Iter=5539968/epoch=87, Loss=0.088126, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5550208/epoch=87, Loss=0.053394, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5560448/epoch=87, Loss=0.082266, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5570688/epoch=87, Loss=0.055247, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5580928/epoch=88, Loss=0.142890, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5591168/epoch=88, Loss=0.096970, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5601408/epoch=88, Loss=0.092963, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5611648/epoch=88, Loss=0.072611, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5621888/epoch=88, Loss=0.092090, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5632128/epoch=88, Loss=0.073630, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5632128/epoch=88, Validation Accuracy=0.669271
# Iter=5642368/epoch=89, Loss=0.017309, Training Accuracy=1.000000, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5652608/epoch=89, Loss=0.060064, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5662848/epoch=89, Loss=0.129077, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5673088/epoch=89, Loss=0.118342, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5683328/epoch=89, Loss=0.191816, Training Accuracy=0.937500, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5693568/epoch=89, Loss=0.131130, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5703808/epoch=90, Loss=0.089286, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5714048/epoch=90, Loss=0.105520, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5724288/epoch=90, Loss=0.071821, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5734528/epoch=90, Loss=0.036530, Training Accuracy=1.000000, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5734528/epoch=90, Validation Accuracy=0.611979
# Iter=5744768/epoch=90, Loss=0.030774, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5755008/epoch=90, Loss=0.078361, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Model saved in file at iteration 5760128: ./tf_resnet_model_iter45001.ckpt
# Iter=5765248/epoch=91, Loss=0.033248, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5775488/epoch=91, Loss=0.069845, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5785728/epoch=91, Loss=0.145273, Training Accuracy=0.945312, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5795968/epoch=91, Loss=0.037748, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5806208/epoch=91, Loss=0.063979, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5816448/epoch=91, Loss=0.059842, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5826688/epoch=92, Loss=0.077280, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5836928/epoch=92, Loss=0.105362, Training Accuracy=0.968750, Top-5 Accuracy=0.992188, lr=0.010000
#
# Iter=5836928/epoch=92, Validation Accuracy=0.640625
# Iter=5847168/epoch=92, Loss=0.069509, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5857408/epoch=92, Loss=0.068035, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5867648/epoch=92, Loss=0.081505, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5877888/epoch=92, Loss=0.065020, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5888128/epoch=92, Loss=0.043855, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5898368/epoch=93, Loss=0.049944, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5908608/epoch=93, Loss=0.155613, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5918848/epoch=93, Loss=0.042752, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5929088/epoch=93, Loss=0.112792, Training Accuracy=0.976562, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=5939328/epoch=93, Loss=0.070122, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=5939328/epoch=93, Validation Accuracy=0.666667
# Iter=5949568/epoch=93, Loss=0.041998, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5959808/epoch=94, Loss=0.048720, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5970048/epoch=94, Loss=0.071890, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5980288/epoch=94, Loss=0.090157, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=5990528/epoch=94, Loss=0.092086, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6000768/epoch=94, Loss=0.098889, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6011008/epoch=94, Loss=0.030827, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6021248/epoch=95, Loss=0.070150, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6031488/epoch=95, Loss=0.087059, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6041728/epoch=95, Loss=0.128210, Training Accuracy=0.968750, Top-5 Accuracy=0.992188, lr=0.010000
#
# Iter=6041728/epoch=95, Validation Accuracy=0.677083
# Iter=6051968/epoch=95, Loss=0.157129, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6062208/epoch=95, Loss=0.076659, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6072448/epoch=95, Loss=0.104049, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6082688/epoch=96, Loss=0.162814, Training Accuracy=0.953125, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6092928/epoch=96, Loss=0.142051, Training Accuracy=0.960938, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=6103168/epoch=96, Loss=0.071930, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6113408/epoch=96, Loss=0.042015, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6123648/epoch=96, Loss=0.028161, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6133888/epoch=96, Loss=0.035928, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6144128/epoch=97, Loss=0.106823, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=6144128/epoch=97, Validation Accuracy=0.669271
# Iter=6154368/epoch=97, Loss=0.092598, Training Accuracy=0.960938, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6164608/epoch=97, Loss=0.032653, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6174848/epoch=97, Loss=0.101417, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6185088/epoch=97, Loss=0.061282, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6195328/epoch=97, Loss=0.066925, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6205568/epoch=97, Loss=0.058937, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6215808/epoch=98, Loss=0.043748, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6226048/epoch=98, Loss=0.164492, Training Accuracy=0.953125, Top-5 Accuracy=0.992188, lr=0.010000
# Iter=6236288/epoch=98, Loss=0.024544, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6246528/epoch=98, Loss=0.075520, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
#
# Iter=6246528/epoch=98, Validation Accuracy=0.617188
# Iter=6256768/epoch=98, Loss=0.048472, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6267008/epoch=98, Loss=0.029077, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6277248/epoch=99, Loss=0.071457, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6287488/epoch=99, Loss=0.096131, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6297728/epoch=99, Loss=0.102503, Training Accuracy=0.968750, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6307968/epoch=99, Loss=0.051033, Training Accuracy=0.976562, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6318208/epoch=99, Loss=0.079901, Training Accuracy=0.992188, Top-5 Accuracy=1.000000, lr=0.010000
# Iter=6328448/epoch=99, Loss=0.038852, Training Accuracy=0.984375, Top-5 Accuracy=1.000000, lr=0.010000
# Optimization Finished!
# Model saved in file: ./tf_resnet_model.ckpt

# %%
 exit()
